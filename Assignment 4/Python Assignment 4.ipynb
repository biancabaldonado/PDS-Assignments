# %% [markdown]
# ### ***Note Before Proceeding***
# 1. Download the "annotations" folder in the GitHub Repository
# 2. Make sure to update the "annotations" variable to the specific path where you downloaded the "Annotations"

# %% [markdown]
# ### **Question 1. How many files the annotations folder has?**

# %%
import os
import glob

# %%
annotations = '/Users/biancabaldonado/Desktop/ESADE/session_4/annotations'
files = [x for x in os.listdir(annotations) if x != '.DS_Store'] #excluding the .DS_Store file, in case this file was autogenerated
print("----Total Number of Files in Annotation Folder----")
print(f'There are {len(files)} files in the folder')
# Out:
# ----Total Number of Files in Annotation Folder----
# There are 206 files in the folder

# %% [markdown]
# ### **Question 2. How many of them follow the name convention?**

# %%
pattern = r'(\d{8})_(\d{6})_SN(\d+)_QUICKVIEW_VISUAL_([\d_]+)_([A-Za-z0-9\-_.]+)\.txt' 

# Extracting all files in the folder, except .DS_Store
annotations = glob.glob('/Users/biancabaldonado/Desktop/ESADE/session_4/annotations/*.txt')
annotations = [x for x in annotations if os.path.basename(x) != '.DS_Store']

correct_convention = []
incorrect_convention = []

for annotation in annotations:
    # extract the file name
    filename = os.path.basename(annotation)
    
    # Search and extract values
    match = re.match(pattern, filename)
    if match:
        correct_convention.append(filename)

print("----Files with Correct Naming Convention----")
print(f'There are {len(correct_convention)} files that follow the naming convention')
# Out:
# ----Files with Correct Naming Convention----
# There are 194 files that follow the naming convention

# %% [markdown]
# ### ***Disclaimer***
#
# All those part of incorrect convention will not be included in the succeeding numbers since they do not follow the naming convention pattern and as such, the numbers in the file are not intuitive and would need further information on how to interpret (only given the corresponding values for those following the naming convention and as such, I have only extracted the data from these)

# %% [markdown]
# ### **Question 3. How many of annotations you have per month and year? Which month has more annotation files?**

# %%
#Disclaimer: Ensure you have a Python version of at least 3.10+ for the match function to work
import re
import glob
import os
from datetime import datetime
from collections import Counter

pattern = r'(\d{8})_(\d{6})_SN(\d+)_QUICKVIEW_VISUAL_([\d_]+)_([A-Za-z0-9\-_.]+)\.txt' 

annotations = glob.glob('/Users/biancabaldonado/Desktop/ESADE/session_4/annotations/*.txt')

ann_datetime = []
total_years = []
total_months = []
total_year_month = []

for annotation in annotations:

    filename = os.path.basename(annotation)
    
    match = re.match(pattern, filename)
    if match:
        date, time, _, _, _ = match.groups()

        datetime_str = date + time 

        datetime_obj = datetime.strptime(datetime_str, "%Y%m%d%H%M%S")

        year = datetime_obj.year
        month = datetime_obj.month
        
        ann_datetime.append((year, month))

total_years = []
total_months = []
total_year_month = []

for year, month in ann_datetime:
    total_years.append(year) 
    total_months.append(month)
    total_year_month.append((year,month))
      
years_count = Counter(total_years)
months_count = Counter(total_months)
yearmonth_count = Counter(total_year_month)

print("----Number of Files per Year----")
for x, y in years_count.items():
    print(f"Year: {x}, Count: {y}")

print("\n----Number of Files per Month----")
for x, y in months_count.items():
    print(f"Month: {x}, Count: {y}") 

print("\n----Number of Files per Year and Month----")
for x, y in yearmonth_count.items():
    print(f"Year & Month: {x}, Count: {y}") 

max_month = max(months_count, key=months_count.get)

def convert_month(month):
    match month:
        case 1:return "January"
        case 2:return "February"
        case 3:return "March"
        case 4:return "April"
        case 5:return "May"
        case 6:return "June"
        case 7:return "July"
        case 8:return "August"
        case 9:return "September"
        case 10:return "October"
        case 11:return "November"
        case 12:return "December"
        case _:return "Error"  

max_month = convert_month(max_month)

print("\n----Month that has the most annotations:----")
print(max_month)
# Out:
# ----Number of Files per Year----
# Year: 2024, Count: 194
#
# ----Number of Files per Month----
# Month: 1, Count: 27
# Month: 6, Count: 52
# Month: 4, Count: 25
# Month: 2, Count: 45
# Month: 3, Count: 17
# Month: 5, Count: 28
#
# ----Number of Files per Year and Month----
# Year & Month: (2024, 1), Count: 27
# Year & Month: (2024, 6), Count: 52
# Year & Month: (2024, 4), Count: 25
# Year & Month: (2024, 2), Count: 45
# Year & Month: (2024, 3), Count: 17
# Year & Month: (2024, 5), Count: 28
#
# ----Month that has the most annotations:----
# June

# %% [markdown]
# ### **Question 4. Create a new annotations folder with multiple folders corresponding to a month.**

# %%
import os
import re
import shutil
from datetime import datetime

pattern = r'(\d{8})_(\d{6})_SN(\d+)_QUICKVIEW_VISUAL_([\d_]+)_([A-Za-z0-9\-_.]+)\.txt'
annotations = '/Users/biancabaldonado/Desktop/ESADE/session_4/annotations'

monthsfolder = ["January", "February", "March", "April", "May", "June", 
                "July", "August", "September", "October", "November", "December"]

for month in monthsfolder:
    os.makedirs(os.path.join(annotations, month), exist_ok=True)

moved_files = 0
ds_store_files = 0
pattern_mismatches = 0
original_paths = {}

for root, dirs, files in os.walk(annotations):
    for filename in files:
        if filename == '.DS_Store':
            ds_store_files += 1
            continue
        
        if filename.endswith('.txt'):
            match = re.match(pattern, filename)
            
            if match:
                date, time, _, _, _ = match.groups()
                datetime_str = date + time
                datetime_obj = datetime.strptime(datetime_str, "%Y%m%d%H%M%S")
                
                month_name = monthsfolder[datetime_obj.month - 1]
                dest_folder = os.path.join(annotations, month_name)
                dest_file_path = os.path.join(dest_folder, filename)

                if not os.path.exists(dest_file_path):
                    src_file_path = os.path.join(root, filename)
                    shutil.move(src_file_path, dest_file_path)
                    original_paths[dest_file_path] = src_file_path
                    moved_files += 1

            else:
                pattern_mismatches += 1

print("----Success: New Annotation Folders per Month Added----")
print(f"\nSummary: \n- {moved_files} files moved to each folder based on the month,")
print(f"- {ds_store_files} '.DS_Store' files skipped,")
print(f"- {pattern_mismatches} files did not match the pattern.")
# Out:
# ----Success: New Annotation Folders per Month Added----
#
# Summary:
# - 194 files moved to each folder based on the month,
# - 1 '.DS_Store' files skipped,
# - 0 files did not match the pattern.

# %% [markdown]
# ### **Question 5. Print all the annotations from the most recent to the oldest one.**

# %%
import os
import re
from datetime import datetime

pattern = r'(\d{8})_(\d{6})_SN(\d+)_QUICKVIEW_VISUAL_([\d_]+)_([A-Za-z0-9\-_.]+)\.txt'
annotations = '/Users/biancabaldonado/Desktop/ESADE/session_4/annotations'

ann_datetime = []

for root, dirs, files in os.walk(annotations):
    for filename in files:
        if filename.endswith('.txt'):
            file_path = os.path.join(root, filename)
            match = re.match(pattern, filename)
            if match:
                date, time, satellite_number, _, _ = match.groups()
                datetime_str = date + time
                datetime_obj = datetime.strptime(datetime_str, "%Y%m%d%H%M%S")
                ann_datetime.append((file_path, datetime_obj))

recent_to_oldest = sorted(ann_datetime, key=lambda x: x[1], reverse=True)

print("----Files Arranged from Recent to Oldest----")
for index, (file_path, datetime_obj) in enumerate(recent_to_oldest, start=1):
    year = datetime_obj.year
    month = datetime_obj.month
    print(f"{index}. {file_path} --> [Year: {year}, Month: {month}]")
# Out:
# ----Files Arranged from Recent to Oldest----
# 1. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240623_215120_SN29_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-10N_596_4134.txt --> [Year: 2024, Month: 6]
# 2. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240623_215102_SN43_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_384_3750.txt --> [Year: 2024, Month: 6]
# 3. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240623_193704_SN27_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_566_3734.txt --> [Year: 2024, Month: 6]
# 4. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240619_215556_SN29_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-10N_742_4460.txt --> [Year: 2024, Month: 6]
# 5. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240619_185757_SN24_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_528_3700.txt --> [Year: 2024, Month: 6]
# 6. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240619_052401_SN30_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-52N_368_4336.txt --> [Year: 2024, Month: 6]
# 7. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240618_215539_SN31_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_452_3740.txt --> [Year: 2024, Month: 6]
# 8. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240618_215539_SN31_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_458_3756.txt --> [Year: 2024, Month: 6]
# 9. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240618_193146_SN27_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_530_3682.txt --> [Year: 2024, Month: 6]
# 10. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240617_211350_SN29_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_724_3614.txt --> [Year: 2024, Month: 6]
# 11. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240617_184443_SN24_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_702_3566.txt --> [Year: 2024, Month: 6]
# 12. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240617_052859_SN29_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-51N_730_4348.txt --> [Year: 2024, Month: 6]
# 13. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240616_213053_SN30_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_460_3792.txt --> [Year: 2024, Month: 6]
# 14. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240616_213047_SN30_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_464_3830.txt --> [Year: 2024, Month: 6]
# 15. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240616_213047_SN30_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_466_3828.txt --> [Year: 2024, Month: 6]
# 16. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240616_213047_SN30_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_466_3826.txt --> [Year: 2024, Month: 6]
# 17. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240616_213047_SN30_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_464_3828.txt --> [Year: 2024, Month: 6]
# 18. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240616_102144_SN28_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-39N_560_2792.txt --> [Year: 2024, Month: 6]
# 19. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240616_102144_SN28_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-39N_558_2794.txt --> [Year: 2024, Month: 6]
# 20. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240616_102144_SN28_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-39N_556_2794.txt --> [Year: 2024, Month: 6]
# 21. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240616_081345_SN27_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-39N_562_2794.txt --> [Year: 2024, Month: 6]
# 22. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240616_081345_SN27_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-39N_562_2792.txt --> [Year: 2024, Month: 6]
# 23. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240616_081345_SN27_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-39N_560_2792.txt --> [Year: 2024, Month: 6]
# 24. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240616_081345_SN27_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-39N_560_2794.txt --> [Year: 2024, Month: 6]
# 25. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240615_173631_SN33_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_546_3742.txt --> [Year: 2024, Month: 6]
# 26. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240614_221436_SN31_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-10N_558_4184.txt --> [Year: 2024, Month: 6]
# 27. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240613_214203_SN43_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_384_3750.txt --> [Year: 2024, Month: 6]
# 28. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240613_192217_SN26_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-10N_560_4178.txt --> [Year: 2024, Month: 6]
# 29. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240613_053340_SN29_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-51N_728_4342.txt --> [Year: 2024, Month: 6]
# 30. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240613_053340_SN29_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-51N_730_4342.txt --> [Year: 2024, Month: 6]
# 31. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240612_185419_SN24_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_554_3610.txt --> [Year: 2024, Month: 6]
# 32. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240612_185400_SN24_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_574_3714.txt --> [Year: 2024, Month: 6]
# 33. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240612_185400_SN24_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_576_3720.txt --> [Year: 2024, Month: 6]
# 34. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240612_185400_SN24_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_578_3722.txt --> [Year: 2024, Month: 6]
# 35. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240612_053829_SN28_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-51N_686_4422.txt --> [Year: 2024, Month: 6]
# 36. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240612_053829_SN28_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-51N_688_4420.txt --> [Year: 2024, Month: 6]
# 37. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240611_215323_SN30_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-10N_702_3948.txt --> [Year: 2024, Month: 6]
# 38. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240611_025943_SN26_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-51N_748_4366.txt --> [Year: 2024, Month: 6]
# 39. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240611_025943_SN26_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-51N_748_4364.txt --> [Year: 2024, Month: 6]
# 40. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240610_191018_SN26_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_384_3750.txt --> [Year: 2024, Month: 6]
# 41. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240609_214259_SN30_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_262_4052.txt --> [Year: 2024, Month: 6]
# 42. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240609_191959_SN27_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_702_3540.txt --> [Year: 2024, Month: 6]
# 43. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240609_191744_SN24_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-10N_564_4194.txt --> [Year: 2024, Month: 6]
# 44. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240608_214614_SN29_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_248_4068.txt --> [Year: 2024, Month: 6]
# 45. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240607_200250_SN27_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-10N_554_4172.txt --> [Year: 2024, Month: 6]
# 46. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240606_180251_SN33_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-10N_556_4180.txt --> [Year: 2024, Month: 6]
# 47. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240605_212717_SN29_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-11N_718_3608.txt --> [Year: 2024, Month: 6]
# 48. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240604_214955_SN29_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-10N_594_4136.txt --> [Year: 2024, Month: 6]
# 49. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240603_215348_SN28_QUICKVIEW_VISUAL_1_6_0_SATL-2KM-11N_346_3786.txt --> [Year: 2024, Month: 6]
# 50. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240603_215226_SN28_QUICKVIEW_VISUAL_1_6_0_SATL-2KM-11N_248_4068.txt --> [Year: 2024, Month: 6]
# 51. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240602_215203_SN30_QUICKVIEW_VISUAL_1_6_0_SATL-2KM-10N_714_3948.txt --> [Year: 2024, Month: 6]
# 52. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/June/20240602_215203_SN30_QUICKVIEW_VISUAL_1_6_0_SATL-2KM-10N_712_3948.txt --> [Year: 2024, Month: 6]
# 53. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240528_191604_SN24_QUICKVIEW_VISUAL_1_6_0_SATL-2KM-11N_344_3836.txt --> [Year: 2024, Month: 5]
# 54. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240528_191448_SN24_QUICKVIEW_VISUAL_1_6_0_SATL-2KM-11N_248_4068.txt --> [Year: 2024, Month: 5]
# 55. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240524_213504_SN29_QUICKVIEW_VISUAL_1_6_0_SATL-2KM-11N_380_3724.txt --> [Year: 2024, Month: 5]
# 56. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240524_213504_SN29_QUICKVIEW_VISUAL_1_6_0_SATL-2KM-11N_378_3724.txt --> [Year: 2024, Month: 5]
# 57. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240521_101252_SN43_QUICKVIEW_VISUAL_1_6_0_SATL-2KM-39N_556_2792.txt --> [Year: 2024, Month: 5]
# 58. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240521_101252_SN43_QUICKVIEW_VISUAL_1_6_0_SATL-2KM-39N_558_2796.txt --> [Year: 2024, Month: 5]
# 59. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240521_052621_SN43_QUICKVIEW_VISUAL_1_6_0_SATL-2KM-51N_730_4342.txt --> [Year: 2024, Month: 5]
# 60. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240520_194539_SN27_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-10N_638_4280.txt --> [Year: 2024, Month: 5]
# 61. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240520_194539_SN27_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-10N_638_4282.txt --> [Year: 2024, Month: 5]
# 62. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240519_214917_SN31_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_500_3600.txt --> [Year: 2024, Month: 5]
# 63. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240519_214917_SN31_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_500_3602.txt --> [Year: 2024, Month: 5]
# 64. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240519_214917_SN31_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_500_3598.txt --> [Year: 2024, Month: 5]
# 65. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240519_191838_SN27_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_718_3608.txt --> [Year: 2024, Month: 5]
# 66. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240519_184534_SN24_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_658_3700.txt --> [Year: 2024, Month: 5]
# 67. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240516_211630_SN28_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_716_3848.txt --> [Year: 2024, Month: 5]
# 68. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240516_190328_SN24_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_262_4052.txt --> [Year: 2024, Month: 5]
# 69. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240514_052716_SN43_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-51N_730_4342.txt --> [Year: 2024, Month: 5]
# 70. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240513_212022_SN29_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_630_3742.txt --> [Year: 2024, Month: 5]
# 71. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240510_191914_SN27_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_712_3566.txt --> [Year: 2024, Month: 5]
# 72. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240510_191908_SN27_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_718_3608.txt --> [Year: 2024, Month: 5]
# 73. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240509_212336_SN29_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_706_3778.txt --> [Year: 2024, Month: 5]
# 74. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240509_193206_SN26_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-10N_562_4196.txt --> [Year: 2024, Month: 5]
# 75. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240508_194502_SN27_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_264_4022.txt --> [Year: 2024, Month: 5]
# 76. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240508_194502_SN27_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_262_4022.txt --> [Year: 2024, Month: 5]
# 77. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240507_191326_SN27_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_718_3608.txt --> [Year: 2024, Month: 5]
# 78. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240506_213507_SN43_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_384_3750.txt --> [Year: 2024, Month: 5]
# 79. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240506_192008_SN26_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-10N_562_4178.txt --> [Year: 2024, Month: 5]
# 80. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/May/20240503_214759_SN28_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_376_3724.txt --> [Year: 2024, Month: 5]
# 81. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240428_215557_SN43_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-10N_726_3862.txt --> [Year: 2024, Month: 4]
# 82. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240428_215426_SN43_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-10N_630_4264.txt --> [Year: 2024, Month: 4]
# 83. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240428_215426_SN43_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-10N_630_4262.txt --> [Year: 2024, Month: 4]
# 84. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240428_215426_SN43_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-10N_634_4282.txt --> [Year: 2024, Month: 4]
# 85. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240428_191026_SN24_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_380_3722.txt --> [Year: 2024, Month: 4]
# 86. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240427_221308_SN31_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-10N_722_3848.txt --> [Year: 2024, Month: 4]
# 87. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240426_215224_SN29_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_244_3818.txt --> [Year: 2024, Month: 4]
# 88. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240423_190101_SN26_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_418_3872.txt --> [Year: 2024, Month: 4]
# 89. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240423_190101_SN26_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_418_3864.txt --> [Year: 2024, Month: 4]
# 90. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240423_190101_SN26_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_418_3860.txt --> [Year: 2024, Month: 4]
# 91. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240423_190101_SN26_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_418_3862.txt --> [Year: 2024, Month: 4]
# 92. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240423_190101_SN26_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_414_3862.txt --> [Year: 2024, Month: 4]
# 93. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240423_190101_SN26_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_416_3864.txt --> [Year: 2024, Month: 4]
# 94. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240423_190101_SN26_QUICKVIEW_VISUAL_1_5_0_SATL-2KM-11N_416_3862.txt --> [Year: 2024, Month: 4]
# 95. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240402_215427_SN31_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-11N_502_3600.txt --> [Year: 2024, Month: 4]
# 96. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240402_215421_SN31_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-11N_500_3632.txt --> [Year: 2024, Month: 4]
# 97. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240402_184757_SN24_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-11N_488_3638.txt --> [Year: 2024, Month: 4]
# 98. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240402_184757_SN24_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-11N_486_3630.txt --> [Year: 2024, Month: 4]
# 99. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240402_184757_SN24_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-11N_486_3636.txt --> [Year: 2024, Month: 4]
# 100. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240402_184757_SN24_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-11N_490_3638.txt --> [Year: 2024, Month: 4]
# 101. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240401_221819_SN31_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-10N_602_4148.txt --> [Year: 2024, Month: 4]
# 102. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240401_175925_SN33_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-10N_542_4168.txt --> [Year: 2024, Month: 4]
# 103. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240401_175918_SN33_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-10N_542_4168.txt --> [Year: 2024, Month: 4]
# 104. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240401_175918_SN33_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-10N_546_4206.txt --> [Year: 2024, Month: 4]
# 105. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/April/20240401_032415_SN27_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-51N_688_4420.txt --> [Year: 2024, Month: 4]
# 106. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/March/20240325_173936_SN33_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-11N_378_3722.txt --> [Year: 2024, Month: 3]
# 107. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/March/20240324_180232_SN33_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-10N_554_4172.txt --> [Year: 2024, Month: 3]
# 108. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/March/20240322_212516_SN28_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-11N_502_3600.txt --> [Year: 2024, Month: 3]
# 109. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/March/20240322_184801_SN24_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-11N_500_3632.txt --> [Year: 2024, Month: 3]
# 110. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/March/20240322_184801_SN24_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-11N_502_3632.txt --> [Year: 2024, Month: 3]
# 111. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/March/20240321_220846_SN31_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-10N_560_4178.txt --> [Year: 2024, Month: 3]
# 112. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/March/20240321_190819_SN27_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-11N_714_3632.txt --> [Year: 2024, Month: 3]
# 113. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/March/20240317_221229_SN31_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-10N_556_4176.txt --> [Year: 2024, Month: 3]
# 114. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/March/20240317_215115_SN28_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-10N_554_4162.txt --> [Year: 2024, Month: 3]
# 115. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/March/20240317_215115_SN28_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-10N_552_4162.txt --> [Year: 2024, Month: 3]
# 116. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/March/20240317_215115_SN28_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-10N_552_4164.txt --> [Year: 2024, Month: 3]
# 117. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/March/20240316_191451_SN26_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-11N_380_3764.txt --> [Year: 2024, Month: 3]
# 118. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/March/20240314_220020_SN30_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-10N_544_4186.txt --> [Year: 2024, Month: 3]
# 119. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/March/20240314_220020_SN30_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-10N_550_4202.txt --> [Year: 2024, Month: 3]
# 120. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/March/20240308_211248_SN29_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-11N_718_3640.txt --> [Year: 2024, Month: 3]
# 121. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/March/20240308_191212_SN27_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-11N_506_3614.txt --> [Year: 2024, Month: 3]
# 122. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/March/20240304_212824_SN30_QUICKVIEW_VISUAL_1_2_0_SATL-2KM-11N_378_3722.txt --> [Year: 2024, Month: 3]
# 123. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240228_213951_SN29_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_248_4068.txt --> [Year: 2024, Month: 2]
# 124. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240227_214218_SN30_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-10N_562_4170.txt --> [Year: 2024, Month: 2]
# 125. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240224_214855_SN30_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-10N_552_4162.txt --> [Year: 2024, Month: 2]
# 126. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240224_214855_SN30_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-10N_554_4162.txt --> [Year: 2024, Month: 2]
# 127. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240223_025420_SN24_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-51N_686_4422.txt --> [Year: 2024, Month: 2]
# 128. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240222_212250_SN30_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_382_3722.txt --> [Year: 2024, Month: 2]
# 129. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240222_074256_SN26_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-39N_564_2790.txt --> [Year: 2024, Month: 2]
# 130. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240222_074155_SN26_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-39N_556_2794.txt --> [Year: 2024, Month: 2]
# 131. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240222_074155_SN26_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-39N_562_2794.txt --> [Year: 2024, Month: 2]
# 132. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240222_074155_SN26_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-39N_556_2792.txt --> [Year: 2024, Month: 2]
# 133. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240222_074155_SN26_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-39N_562_2792.txt --> [Year: 2024, Month: 2]
# 134. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240222_074155_SN26_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-39N_560_2792.txt --> [Year: 2024, Month: 2]
# 135. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240222_074155_SN26_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-39N_558_2794.txt --> [Year: 2024, Month: 2]
# 136. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240222_074151_SN26_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-39N_560_2794.txt --> [Year: 2024, Month: 2]
# 137. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240222_074151_SN26_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-39N_560_2796.txt --> [Year: 2024, Month: 2]
# 138. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240222_074151_SN26_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-39N_558_2796.txt --> [Year: 2024, Month: 2]
# 139. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240222_074151_SN26_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-39N_556_2794.txt --> [Year: 2024, Month: 2]
# 140. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240222_074151_SN26_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-39N_562_2794.txt --> [Year: 2024, Month: 2]
# 141. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240221_190608_SN26_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_380_3764.txt --> [Year: 2024, Month: 2]
# 142. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240220_190455_SN27_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_718_3608.txt --> [Year: 2024, Month: 2]
# 143. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240219_214312_SN28_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_252_3954.txt --> [Year: 2024, Month: 2]
# 144. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240218_180121_SN33_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-10N_568_4176.txt --> [Year: 2024, Month: 2]
# 145. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240216_213630_SN31_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_418_3724.txt --> [Year: 2024, Month: 2]
# 146. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240214_184340_SN24_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_688_3630.txt --> [Year: 2024, Month: 2]
# 147. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240213_212524_SN29_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_542_3750.txt --> [Year: 2024, Month: 2]
# 148. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240213_212524_SN29_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_544_3742.txt --> [Year: 2024, Month: 2]
# 149. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240213_212524_SN29_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_540_3748.txt --> [Year: 2024, Month: 2]
# 150. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240212_213506_SN31_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_408_3712.txt --> [Year: 2024, Month: 2]
# 151. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240211_211057_SN30_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_700_3690.txt --> [Year: 2024, Month: 2]
# 152. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240209_212744_SN29_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_380_3722.txt --> [Year: 2024, Month: 2]
# 153. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240208_184650_SN24_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_624_3632.txt --> [Year: 2024, Month: 2]
# 154. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240203_173953_SN33_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_368_3756.txt --> [Year: 2024, Month: 2]
# 155. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240203_173953_SN33_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_366_3756.txt --> [Year: 2024, Month: 2]
# 156. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240202_191114_SN27_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_718_3608.txt --> [Year: 2024, Month: 2]
# 157. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240202_184725_SN24_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_624_3630.txt --> [Year: 2024, Month: 2]
# 158. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240201_075143_SN26_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-39N_556_2792.txt --> [Year: 2024, Month: 2]
# 159. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240201_075143_SN26_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-39N_562_2788.txt --> [Year: 2024, Month: 2]
# 160. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240201_075140_SN26_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-39N_558_2794.txt --> [Year: 2024, Month: 2]
# 161. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240201_075140_SN26_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-39N_560_2792.txt --> [Year: 2024, Month: 2]
# 162. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240201_075140_SN26_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-39N_560_2794.txt --> [Year: 2024, Month: 2]
# 163. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240201_075140_SN26_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-39N_560_2796.txt --> [Year: 2024, Month: 2]
# 164. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240201_075140_SN26_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-39N_556_2794.txt --> [Year: 2024, Month: 2]
# 165. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240201_075140_SN26_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-39N_562_2794.txt --> [Year: 2024, Month: 2]
# 166. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240201_075140_SN26_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-39N_556_2792.txt --> [Year: 2024, Month: 2]
# 167. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/February/20240201_075140_SN26_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-39N_562_2792.txt --> [Year: 2024, Month: 2]
# 168. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240130_215036_SN31_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_366_3756.txt --> [Year: 2024, Month: 1]
# 169. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240130_173903_SN33_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_366_3756.txt --> [Year: 2024, Month: 1]
# 170. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240130_173903_SN33_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_360_3748.txt --> [Year: 2024, Month: 1]
# 171. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240130_173903_SN33_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_364_3754.txt --> [Year: 2024, Month: 1]
# 172. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240128_213258_SN29_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_418_3864.txt --> [Year: 2024, Month: 1]
# 173. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240128_213258_SN29_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_418_3862.txt --> [Year: 2024, Month: 1]
# 174. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240127_190620_SN27_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_500_3600.txt --> [Year: 2024, Month: 1]
# 175. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240127_190620_SN27_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_500_3602.txt --> [Year: 2024, Month: 1]
# 176. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240127_190620_SN27_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_502_3602.txt --> [Year: 2024, Month: 1]
# 177. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240127_190620_SN27_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_502_3600.txt --> [Year: 2024, Month: 1]
# 178. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240126_173752_SN33_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_386_3722.txt --> [Year: 2024, Month: 1]
# 179. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240115_213834_SN28_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_376_3722.txt --> [Year: 2024, Month: 1]
# 180. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240115_213834_SN28_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_380_3724.txt --> [Year: 2024, Month: 1]
# 181. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240112_192510_SN27_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_386_3750.txt --> [Year: 2024, Month: 1]
# 182. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240110_192002_SN27_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_380_3728.txt --> [Year: 2024, Month: 1]
# 183. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240104_220339_SN31_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-10N_556_4178.txt --> [Year: 2024, Month: 1]
# 184. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240102_185954_SN24_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_414_3786.txt --> [Year: 2024, Month: 1]
# 185. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240102_185605_SN27_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_690_3572.txt --> [Year: 2024, Month: 1]
# 186. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240102_185527_SN27_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_740_3850.txt --> [Year: 2024, Month: 1]
# 187. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240101_213601_SN31_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_392_3740.txt --> [Year: 2024, Month: 1]
# 188. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240101_213601_SN31_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_392_3742.txt --> [Year: 2024, Month: 1]
# 189. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240101_213601_SN31_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_396_3752.txt --> [Year: 2024, Month: 1]
# 190. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240101_192856_SN24_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-10N_552_4164.txt --> [Year: 2024, Month: 1]
# 191. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240101_192856_SN24_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-10N_552_4162.txt --> [Year: 2024, Month: 1]
# 192. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240101_192856_SN24_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-10N_554_4162.txt --> [Year: 2024, Month: 1]
# 193. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240101_174301_SN33_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_404_3770.txt --> [Year: 2024, Month: 1]
# 194. /Users/biancabaldonado/Desktop/ESADE/session_4/annotations/January/20240101_174301_SN33_QUICKVIEW_VISUAL_1_1_10_SATL-2KM-11N_404_3772.txt --> [Year: 2024, Month: 1]

# %% [markdown]
# ### **Question 6. How many different satellites there are, how many annotations we have per satellite number, and which one was used in the most recent annotation file.**

# %%
import os
import re
from collections import Counter
from datetime import datetime

pattern = r'(\d{8})_(\d{6})_SN(\d+)_QUICKVIEW_VISUAL_([\d_]+)_([A-Za-z0-9\-_.]+)\.txt'
annotations = '/Users/biancabaldonado/Desktop/ESADE/session_4/annotations'

monthsfolder = ["January", "February", "March", "April", "May", "June", 
                "July", "August", "September", "October", "November", "December"]

satellites = []
ann_datetime = []

for root, dirs, files in os.walk(annotations):
    for filename in files:
        if filename == '.DS_Store':  
            continue
        if filename.endswith('.txt'):
            match = re.match(pattern, filename)
            if match:
                date, time, satellite_number, _, _ = match.groups()
                datetime_str = date + time
                datetime_obj = datetime.strptime(datetime_str, "%Y%m%d%H%M%S")
                
                ann_datetime.append((filename, datetime_obj, satellite_number))
                satellites.append(satellite_number)

satellites_count = Counter(satellites)

print("----Number of Unique Satellites----")
print(len(satellites_count))

print("\n----List of Unique Satellites----")
for satellite_number in sorted(set(satellites)):  
    print(f"Satellite Number: {satellite_number}")  

print("\n----Number of Files per Satellite----")
for satellite_number, count in sorted(satellites_count.items()):
    print(f"Satellite Number: {satellite_number}, Count: {count}")

pattern2 = r'SN\d+'

recent_to_oldest = sorted(ann_datetime, key=lambda x: x[1], reverse=True)  

most_recent_filename = recent_to_oldest[0][0]
match = re.search(pattern2, most_recent_filename)

print("\n----Satellite Number of Most Recent File----")
if match:
    sn_number = match.group(0)
    print(f"Satellite Number: {sn_number}, File Name: {most_recent_filename}")
# Out:
# ----Number of Unique Satellites----
# 9
#
# ----List of Unique Satellites----
# Satellite Number: 24
# Satellite Number: 26
# Satellite Number: 27
# Satellite Number: 28
# Satellite Number: 29
# Satellite Number: 30
# Satellite Number: 31
# Satellite Number: 33
# Satellite Number: 43
#
# ----Number of Files per Satellite----
# Satellite Number: 24, Count: 26
# Satellite Number: 26, Count: 37
# Satellite Number: 27, Count: 29
# Satellite Number: 28, Count: 16
# Satellite Number: 29, Count: 22
# Satellite Number: 30, Count: 18
# Satellite Number: 31, Count: 19
# Satellite Number: 33, Count: 16
# Satellite Number: 43, Count: 11
#
# ----Satellite Number of Most Recent File----
# Satellite Number: SN29, File Name: 20240623_215120_SN29_QUICKVIEW_VISUAL_1_7_0_SATL-2KM-10N_596_4134.txt

# %% [markdown]
# ### **Question 7. How many unique regions there are.**

# %%
import os
import re
from collections import Counter

pattern = r'(\d{8})_(\d{6})_SN(\d+)_QUICKVIEW_VISUAL_([\d_]+)_([A-Za-z0-9\-_.]+)\.txt'

annotations = '/Users/biancabaldonado/Desktop/ESADE/session_4/annotations'

annotations_list = []

for root, dirs, files in os.walk(annotations):
    for filename in files:
        if filename.endswith('.txt'):  
            annotations_list.append(os.path.join(root, filename))

regions = []

for annotation in annotations_list:
    filename = os.path.basename(annotation) 

    match = re.match(pattern, filename) 
    if match:
        _, _, _, _, unique_region = match.groups() 
        regions.append(unique_region) 

regions_count = Counter(regions)

print("\n----Number of Unique Regions:----")
print(len(regions_count))  

print("\n----Value Count per Unique Region:----")
for region, count in sorted(regions_count.items()):
    print(f"Region: {region}, Count: {count}")
# Out:
# ----Number of Unique Regions:----
# 137
#
# ----Value Count per Unique Region:----
# Region: SATL-2KM-10N_542_4168, Count: 2
# Region: SATL-2KM-10N_544_4186, Count: 1
# Region: SATL-2KM-10N_546_4206, Count: 1
# Region: SATL-2KM-10N_550_4202, Count: 1
# Region: SATL-2KM-10N_552_4162, Count: 3
# Region: SATL-2KM-10N_552_4164, Count: 2
# Region: SATL-2KM-10N_554_4162, Count: 3
# Region: SATL-2KM-10N_554_4172, Count: 2
# Region: SATL-2KM-10N_556_4176, Count: 1
# Region: SATL-2KM-10N_556_4178, Count: 1
# Region: SATL-2KM-10N_556_4180, Count: 1
# Region: SATL-2KM-10N_558_4184, Count: 1
# Region: SATL-2KM-10N_560_4178, Count: 2
# Region: SATL-2KM-10N_562_4170, Count: 1
# Region: SATL-2KM-10N_562_4178, Count: 1
# Region: SATL-2KM-10N_562_4196, Count: 1
# Region: SATL-2KM-10N_564_4194, Count: 1
# Region: SATL-2KM-10N_568_4176, Count: 1
# Region: SATL-2KM-10N_594_4136, Count: 1
# Region: SATL-2KM-10N_596_4134, Count: 1
# Region: SATL-2KM-10N_602_4148, Count: 1
# Region: SATL-2KM-10N_630_4262, Count: 1
# Region: SATL-2KM-10N_630_4264, Count: 1
# Region: SATL-2KM-10N_634_4282, Count: 1
# Region: SATL-2KM-10N_638_4280, Count: 1
# Region: SATL-2KM-10N_638_4282, Count: 1
# Region: SATL-2KM-10N_702_3948, Count: 1
# Region: SATL-2KM-10N_712_3948, Count: 1
# Region: SATL-2KM-10N_714_3948, Count: 1
# Region: SATL-2KM-10N_722_3848, Count: 1
# Region: SATL-2KM-10N_726_3862, Count: 1
# Region: SATL-2KM-10N_742_4460, Count: 1
# Region: SATL-2KM-11N_244_3818, Count: 1
# Region: SATL-2KM-11N_248_4068, Count: 4
# Region: SATL-2KM-11N_252_3954, Count: 1
# Region: SATL-2KM-11N_262_4022, Count: 1
# Region: SATL-2KM-11N_262_4052, Count: 2
# Region: SATL-2KM-11N_264_4022, Count: 1
# Region: SATL-2KM-11N_344_3836, Count: 1
# Region: SATL-2KM-11N_346_3786, Count: 1
# Region: SATL-2KM-11N_360_3748, Count: 1
# Region: SATL-2KM-11N_364_3754, Count: 1
# Region: SATL-2KM-11N_366_3756, Count: 3
# Region: SATL-2KM-11N_368_3756, Count: 1
# Region: SATL-2KM-11N_376_3722, Count: 1
# Region: SATL-2KM-11N_376_3724, Count: 1
# Region: SATL-2KM-11N_378_3722, Count: 2
# Region: SATL-2KM-11N_378_3724, Count: 1
# Region: SATL-2KM-11N_380_3722, Count: 2
# Region: SATL-2KM-11N_380_3724, Count: 2
# Region: SATL-2KM-11N_380_3728, Count: 1
# Region: SATL-2KM-11N_380_3764, Count: 2
# Region: SATL-2KM-11N_382_3722, Count: 1
# Region: SATL-2KM-11N_384_3750, Count: 4
# Region: SATL-2KM-11N_386_3722, Count: 1
# Region: SATL-2KM-11N_386_3750, Count: 1
# Region: SATL-2KM-11N_392_3740, Count: 1
# Region: SATL-2KM-11N_392_3742, Count: 1
# Region: SATL-2KM-11N_396_3752, Count: 1
# Region: SATL-2KM-11N_404_3770, Count: 1
# Region: SATL-2KM-11N_404_3772, Count: 1
# Region: SATL-2KM-11N_408_3712, Count: 1
# Region: SATL-2KM-11N_414_3786, Count: 1
# Region: SATL-2KM-11N_414_3862, Count: 1
# Region: SATL-2KM-11N_416_3862, Count: 1
# Region: SATL-2KM-11N_416_3864, Count: 1
# Region: SATL-2KM-11N_418_3724, Count: 1
# Region: SATL-2KM-11N_418_3860, Count: 1
# Region: SATL-2KM-11N_418_3862, Count: 2
# Region: SATL-2KM-11N_418_3864, Count: 2
# Region: SATL-2KM-11N_418_3872, Count: 1
# Region: SATL-2KM-11N_452_3740, Count: 1
# Region: SATL-2KM-11N_458_3756, Count: 1
# Region: SATL-2KM-11N_460_3792, Count: 1
# Region: SATL-2KM-11N_464_3828, Count: 1
# Region: SATL-2KM-11N_464_3830, Count: 1
# Region: SATL-2KM-11N_466_3826, Count: 1
# Region: SATL-2KM-11N_466_3828, Count: 1
# Region: SATL-2KM-11N_486_3630, Count: 1
# Region: SATL-2KM-11N_486_3636, Count: 1
# Region: SATL-2KM-11N_488_3638, Count: 1
# Region: SATL-2KM-11N_490_3638, Count: 1
# Region: SATL-2KM-11N_500_3598, Count: 1
# Region: SATL-2KM-11N_500_3600, Count: 2
# Region: SATL-2KM-11N_500_3602, Count: 2
# Region: SATL-2KM-11N_500_3632, Count: 2
# Region: SATL-2KM-11N_502_3600, Count: 3
# Region: SATL-2KM-11N_502_3602, Count: 1
# Region: SATL-2KM-11N_502_3632, Count: 1
# Region: SATL-2KM-11N_506_3614, Count: 1
# Region: SATL-2KM-11N_528_3700, Count: 1
# Region: SATL-2KM-11N_530_3682, Count: 1
# Region: SATL-2KM-11N_540_3748, Count: 1
# Region: SATL-2KM-11N_542_3750, Count: 1
# Region: SATL-2KM-11N_544_3742, Count: 1
# Region: SATL-2KM-11N_546_3742, Count: 1
# Region: SATL-2KM-11N_554_3610, Count: 1
# Region: SATL-2KM-11N_566_3734, Count: 1
# Region: SATL-2KM-11N_574_3714, Count: 1
# Region: SATL-2KM-11N_576_3720, Count: 1
# Region: SATL-2KM-11N_578_3722, Count: 1
# Region: SATL-2KM-11N_624_3630, Count: 1
# Region: SATL-2KM-11N_624_3632, Count: 1
# Region: SATL-2KM-11N_630_3742, Count: 1
# Region: SATL-2KM-11N_658_3700, Count: 1
# Region: SATL-2KM-11N_688_3630, Count: 1
# Region: SATL-2KM-11N_690_3572, Count: 1
# Region: SATL-2KM-11N_700_3690, Count: 1
# Region: SATL-2KM-11N_702_3540, Count: 1
# Region: SATL-2KM-11N_702_3566, Count: 1
# Region: SATL-2KM-11N_706_3778, Count: 1
# Region: SATL-2KM-11N_712_3566, Count: 1
# Region: SATL-2KM-11N_714_3632, Count: 1
# Region: SATL-2KM-11N_716_3848, Count: 1
# Region: SATL-2KM-11N_718_3608, Count: 6
# Region: SATL-2KM-11N_718_3640, Count: 1
# Region: SATL-2KM-11N_724_3614, Count: 1
# Region: SATL-2KM-11N_740_3850, Count: 1
# Region: SATL-2KM-39N_556_2792, Count: 4
# Region: SATL-2KM-39N_556_2794, Count: 4
# Region: SATL-2KM-39N_558_2794, Count: 3
# Region: SATL-2KM-39N_558_2796, Count: 2
# Region: SATL-2KM-39N_560_2792, Count: 4
# Region: SATL-2KM-39N_560_2794, Count: 3
# Region: SATL-2KM-39N_560_2796, Count: 2
# Region: SATL-2KM-39N_562_2788, Count: 1
# Region: SATL-2KM-39N_562_2792, Count: 3
# Region: SATL-2KM-39N_562_2794, Count: 4
# Region: SATL-2KM-39N_564_2790, Count: 1
# Region: SATL-2KM-51N_686_4422, Count: 2
# Region: SATL-2KM-51N_688_4420, Count: 2
# Region: SATL-2KM-51N_728_4342, Count: 1
# Region: SATL-2KM-51N_730_4342, Count: 3
# Region: SATL-2KM-51N_730_4348, Count: 1
# Region: SATL-2KM-51N_748_4364, Count: 1
# Region: SATL-2KM-51N_748_4366, Count: 1
# Region: SATL-2KM-52N_368_4336, Count: 1

# %% [markdown]
# ### **Undoing Moving of Files to Folder**
# - Make sure to run this code at the end so that when the code is ran again, files are moved back to its original location

# %%
import os
import shutil

annotations = '/Users/biancabaldonado/Desktop/ESADE/session_4/annotations'
monthsfolder = ["January", "February", "March", "April", "May", "June", 
                "July", "August", "September", "October", "November", "December"]

moved_back_files = 0

# Iterate through each month folder and move files back to main annotations directory
for month in monthsfolder:
    month_folder_path = os.path.join(annotations, month)
    if os.path.exists(month_folder_path):  # Check if the monthly folder exists
        for filename in os.listdir(month_folder_path):
            file_path = os.path.join(month_folder_path, filename)
            if filename.endswith('.txt'):  # Only move .txt files
                dest_path = os.path.join(annotations, filename)
                shutil.move(file_path, dest_path)
                moved_back_files += 1

print(f"----Undo Complete: {moved_back_files} Files Moved Back to Main Annotations Directory----")
# Out:
# ----Undo Complete: 194 Files Moved Back to Main Annotations Directory----
